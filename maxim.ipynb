# %%
######### IMPORT ###########
from collections import deque
import random
import pandas as pd  # package for some uses and maybe for visualization
import numpy as np
import heapq
from matplotlib.pylab import plot, show, bar
import matplotlib.pyplot as plt
plt.style.use("ggplot")


np.random.seed(1)

# %%
df = pd.read_csv('arrival_rates.csv')
df  
floors_num = 25
arrival_rates_by_floor_section = [
    [18, 10.8, 40.8], [50, 6.8, 12.8], [11, 4.8, 7.8]]
arrival_rates = [
    [[], []],
    [[], [], []],
    [[], [], []]
]
k = -1
for i in range(3):
    for j in range(len(arrival_rates[i])):
        k += 1
        if k == 8:
            break
        opc = [df.loc[k, "other"], df.loc[k, "15--18"], df.loc[k, "7--10"]]
        arrival_rates[i][j].extend(opc)
arrival_rates[0].insert(0, None)
# Creating a dictionary with the range of each floor
# the range ressembles the location in the rate array
lower_floor_range = {floor: 1 for floor in range(1, 16)}
upper_floor_range = {floor: 2 for floor in range(16, 26)}
lower_floor_range.update(upper_floor_range)
floor_range = lower_floor_range
floor_range[0] = 0  # ground floor

# %%
######### CLASS ###########
class Event():
    def __init__(self, time, eventType, passenger=-1, elevator=-1):
        self.time = time  # event time
        self.eventType = eventType  # type of the event
        self.passenger = passenger
        self.elevator = elevator
        heapq.heappush(P, self)  # add the event to the events list

    def __lt__(self, event2):
        return self.time < event2.time

########################
#### Passenger class ###
########################


class Passenger(object):
    def __init__(self, start, end, arrival_time):
        self.id = passenger_count  # unique identifier
        self.start = start
        self.end = end
        self.arrival_time = arrival_time  # time of first arrival
        # self.current_floor = floor
        self.in_journey = (start != 0 and end != 0) and ((
            start > 15 and end <= 15) or (start <= 15 and end > 15))
        # self.journey_started = False  # describes the current part of the journey. Either 1 or 2
        self.left = False
        self.started_using_sys = False
        if self.in_journey:
            # in journey
            # always going down firt to floor 0
            self.direction = -1
        else:
            # not in journey
            if end > start:
                self.direction = 1
            else:
                self.direction = -1


class Elevator(object):
    def __init__(self, id, starting_floor, direction, top_floor):
        self.id = id
        self.curr_floor = starting_floor
        self.prev_floor = starting_floor
        self.stop_time = curr_time  # last stop time
        self.passengers = []
        self.max_capacity = 15
        self.remaining_space = self.max_capacity - len(self.passengers)
        self.direction = direction  # up / down
        self.is_top_elevator = top_floor == 25
        self.top_floor = top_floor
        if top_floor == 15:
            self.min_floor = 1  # lowest floor in section
        else:
            self.min_floor = 16  # lowest floor in section
        self.is_broken = False  # elevator starts un-broken
        self.last_broken_time = -1  # time of last break

    # Gets the elevator destination. Checks if it was broken until arriving
    def update_space(self):
        self.remaining_space = self.max_capacity - len(self.passengers)

    def move(self):
        self.prev_floor = self.curr_floor
        if self.is_top_elevator:
            if self.curr_floor == 16 and self.direction == -1:
                self.curr_floor -= 15  # move the elevator past sector #1
            elif self.curr_floor == 0 and self.direction == 1:
                self.curr_floor += 15  # move the elevator past sector #1
        self.curr_floor += self.direction
        if (self.curr_floor == 0 and self.direction == -1) or (self.curr_floor in [15, 25] and self.direction == 1):
            # if reached end of section, flip direction
            self.direction *= -1

    def did_break(self):
        if self.is_broken:
            # it's now fixed after being broken
            self.is_broken = False
            return False
        else:
            # elevator has been working until now
            rnd = np.random.random()
            if rnd < 0.0005:
                # and now it broke
                self.is_broken = True
                self.last_broken_time = curr_time
                return True
            else:
                # still not broken
                return False

    def switch_direction(self):
        self.direction *= -1

    # removes leaving passengers and returns journey passengers
    def release_passengers(self):
        # count the passengers just before they leave
        elevator_usage[self.id -
                       1][len(self.passengers)-1] += curr_time - self.stop_time
        leaving_passengers = list(
            [p for p in self.passengers if self.curr_floor == p.end])  # for visualization
        for p in leaving_passengers:
            service_time.append(curr_time - p.arrival_time)

        journey_passengers = []
        if self.curr_floor == 0:
            # journey passengers are saved in the system
            journey_passengers = list(
                [p for p in self.passengers if p.in_journey])
            self.passengers = list(
                [p for p in self.passengers if self.curr_floor != p.end and not p.in_journey])
        else:
            # create new passengers list with all the passengers that stay
            self.passengers = list(
                [p for p in self.passengers if self.curr_floor != p.end])

        return journey_passengers

     # removes passengers in the broken elevator to the other elevator
    def release_when_broken(self, direction):
        # count the passengers before they leave
        elevator_usage[self.id -
                       1][len(self.passengers)-1] += curr_time - self.stop_time
        # release only passengers that go to the same direction as the rescue elevator
        released = list(
            [p for p in self.passengers if self.direction == direction])
        self.passengers = list(
            [p for p in self.passengers if self.curr_floor != p.end and not self.direction == direction])
        return released

######### FUNCTION ###########

## returns current rate ##
##########################


def get_current_rate_by_floor(start_floor, end_floor):
    # get current arrival rate according to start floor,
    # destination, (or section) and curr_time(which would be determined
    # at the start of each While iteration)
    start_floor_section = floor_range[start_floor]
    end_floor_section = floor_range[end_floor]
    if curr_time >= 60*60 and curr_time < 4*60*60:
        # 07:00-10:00
        hour_range = 2
    elif curr_time >= 9*60*60 and curr_time < 12*60*60:
        # 15:00-18:00
        hour_range = 1
    else:
        # any other time
        hour_range = 0

    rate = arrival_rates[start_floor_section][end_floor_section][hour_range]
    # Convert to exponential rate
    return (60*60)/rate

# returns a random destination in the same section


def get_rand_dest(end):
    if end == 0:
        return 0
    elif end > 15:
        return np.random.randint(16, 26)
    else:
        return np.random.randint(1, 16)


def get_travel_time(floors):
    start = 2
    stop = 2
    wait = 5
    pass_by = 1
    return floors * pass_by + start + stop + wait


#### Performance Measures ####
service_time = []  # for visualization - service time for each passenger
avg_service = []  # for visualization - avg service duration
avg_out_of_patience = [0]*100  # out of patience per day
elevator_usage =  [[0]*16, [0]*16, [0]*16, [0]*16]
##############################


for i in range(100):

    ######### INITIATE ###########
    # initialize simulation
    curr_time = 0  # current time
    SIM_TIME = 14*60*60  # simulation time in minutes

    P = []  # heap
    L_up = [[] for _ in range(26)]  # going up line in every floor
    # at floor zero we have 2 seperate lines for the 2 pairs of elevator
    L_up[0] = [[], []]
    L_down = [[] for _ in range(26)]  # going down line in every floor
    passenger_count = 0

    # create list of elevators
    elevators = [Elevator(id=1, starting_floor=0, direction=1, top_floor=15), Elevator(id=2, starting_floor=15, direction=-1, top_floor=15), Elevator(
        id=3, starting_floor=0, direction=1, top_floor=25), Elevator(id=4, starting_floor=25, direction=-1, top_floor=25)]

    for start in range(0, 26):
        for end in range(0, 26):
            if start == end:
                continue
            time = np.random.exponential(get_current_rate_by_floor(start, end))
            new_passenger = Passenger(start, end, time)
            passenger_count += 1
            Event(time, "arriving", passenger=new_passenger)

    for elevator in elevators:
        # init elevators
        Event(curr_time + 5, "elevator_close", elevator=elevator)

    ######### LOOP ###########
    while curr_time < SIM_TIME:  # loop until sim time ends
        # print(passenger_count)

        event = heapq.heappop(P)  # get next event
        curr_time = event.time  # current event's time

        ## arriving ##
        if event.eventType == "arriving":
            passenger = event.passenger
            # insert passenger to floor line
            if passenger.direction == 1:
                if passenger.start == 0:
                    # passenger is going up on floor zero
                    heapq.heappush(
                        L_up[0][1 if passenger.end > 15 else 0], (passenger.arrival_time, id(passenger), passenger))
                else:
                    heapq.heappush(
                        L_up[passenger.start], (passenger.arrival_time, id(passenger), passenger))
            else:
                heapq.heappush(L_down[passenger.start],
                               (passenger.arrival_time, id(passenger), passenger))
            # check if he will be out of patience
            Event(curr_time + 15*60, "out_of_patience", passenger)
            # generate next passenger
            rate = get_current_rate_by_floor(passenger.start, passenger.end)
            new_time = curr_time + np.random.exponential(rate)
            new_passenger = Passenger(passenger.start, passenger.end, new_time)
            passenger_count += 1
            Event(new_time, "arriving", passenger=new_passenger)
            ##############

        ## elevator_close ##
        elif event.eventType == "elevator_close":
            elevator = event.elevator

            is_broken = elevator.did_break()
            # passengers with this destination are free to go, returns journey passengers in floor 0
            journey_passengers = elevator.release_passengers()
            if elevator.curr_floor == 0:
                # if in floor 0, add journey passengers to queue
                for j_passenger in journey_passengers:
                    # add journey passengers back to the line
                    # they always go up if in middle of journey
                    j_passenger.in_journey = False
                    j_passenger.direction = 1
                    heapq.heappush(L_up[0][1 if j_passenger.end > 15 else 0],
                                   (curr_time - 5, id(j_passenger), j_passenger))
            # pull passengers from broken elevator
            for other_elevator in elevators:
                if other_elevator != elevator and other_elevator.top_floor == elevator.top_floor:
                    if other_elevator.is_broken and other_elevator.curr_floor == elevator.curr_floor and other_elevator.direction == elevator.direction:
                        # other elevator is stuck right now on same floor and with same direction
                        # and also the current elevator didnt break
                        # therefore we will take any passenger we can with us
                        released_from_broken = other_elevator.release_when_broken(
                            elevator.direction)
                        # add another counting point for passengers leaving to another elevator
                        other_elevator.stop_time = curr_time
                        for p in released_from_broken:
                            elevator.update_space()
                            if elevator.remaining_space > 0:
                                # both are going in the same direction
                                # passenger enters the elevator
                                # appends randomly
                                elevator.passengers.append(p)
                            else:
                                # return these passengers back to home elevator
                                other_elevator.passengers.append(p)

            if is_broken:
                # handle elevator broken
                fix_time = curr_time + np.random.uniform(5, 15)*60
                Event(fix_time, "elevator_close", elevator=elevator)
                # if elevator is stuck, it won't be moving
            else:  # not stuck
                if elevator.direction == 1:  # list of customers in line
                    if elevator.curr_floor == 0:  # if floor is zero - we have 2 seperate up lines
                        waiting_passengers = L_up[0][1 if elevator.is_top_elevator else 0]
                    else:
                        waiting_passengers = L_up[elevator.curr_floor]
                else:
                    waiting_passengers = L_down[elevator.curr_floor]
                while waiting_passengers:
                    elevator.update_space()
                    if elevator.remaining_space > 0:
                        # both are going in the same direction
                        # passenger enters the elevator
                        # returns the passenger from tuple

                        next_in_line = heapq.heappop(waiting_passengers)[2]
                        # passengers started using the elevators and wont run out of patience
                        next_in_line.started_using_sys = True
                        elevator.passengers.append(next_in_line)
                    else:
                        break  # stop inserting passengers to elevator, no room or no more passengers
                if (elevator.curr_floor == 16 and elevator.direction == -1) or (elevator.curr_floor == 0 and elevator.direction == 1 and elevator.is_top_elevator):
                    next_time = curr_time + get_travel_time(floors=16)
                else:
                    next_time = curr_time + get_travel_time(floors=1)
                # if not broken, move as scheduled to next floor
                Event(next_time, "elevator_close", elevator=elevator)
                elevator.stop_time = curr_time
                elevator.move()  # moves elevator to next floor + open + close doors

        ## out_of_patience ##
        elif event.eventType == "out_of_patience":
            passenger = event.passenger
            if passenger.left is False and passenger.started_using_sys is False:
                passenger.left = True
                # will always be next passenger
                if passenger.direction == 1:
                    if passenger.start == 0:
                        for p_tuple in L_up[0][1 if passenger.end > 15 else 0]:
                            if p_tuple[2] == passenger:
                                L_up[0][1 if passenger.end >
                                        15 else 0].remove(p_tuple)
                        heapq.heapify(L_up[passenger.start][1 if passenger.end >
                                                            15 else 0])
                    else:
                        for p_tuple in L_up[passenger.start]:
                            if p_tuple[2] == passenger:
                                L_up[passenger.start].remove(p_tuple)
                        heapq.heapify(L_up[passenger.start])
                else:
                    for p_tuple in L_down[passenger.start]:
                        if p_tuple[2] == passenger:
                            L_down[passenger.start].remove(p_tuple)
                    heapq.heapify(L_down[passenger.start])
                avg_out_of_patience[i] += 1  # for visualization
                service_time.append(curr_time - passenger.arrival_time)
    ##############
# Out:
# or is broken  44675.59148339523
#  elevator is broken  45637.5699265711
#  elevator is broken  1485
#  elevator is broken  2110
#  elevator is broken  11920.87328826429
#  elevator is broken  12263.096561537463
#  elevator is broken  19145
#  elevator is broken  21605
#  elevator is broken  24401.25287302608
#  elevator is broken  25602.7740892165
#  elevator is broken  27493.282332172428
#  elevator is broken  28334.0915162848
#  elevator is broken  30117.6722947361
#  elevator is broken  39645.44953984517
#  elevator is broken  45996.484928456695
#  elevator is broken  47309.42440013707
#  elevator is broken  48781.89033036797
#  elevator is broken  49358.97844272553
#  elevator is broken  49831.88489838261
#  elevator is broken  14275
#  elevator is broken  20925
#  elevator is broken  21900
#  elevator is broken  29935
#  elevator is broken  35670.326232376494
#  elevator is broken  39850.185409743724
#  elevator is broken  2635
#  elevator is broken  2715
#  elevator is broken  7365
#  elevator is broken  12888.255974267158
#  elevator is broken  17366.492592701296
#  elevator is broken  22416.77415424202
#  elevator is broken  28265.48026704011
#  elevator is broken  31828.488172658308
#  elevator is broken  355
#  elevator is broken  3644.0801674235818
#  elevator is broken  11400
#  elevator is broken  15475
#  elevator is broken  16673.716503150605
#  elevator is broken  24815
#  elevator is broken  27443.15102614541
#  elevator is broken  30763.50230339294
#  elevator is broken  35064.64787030463
#  elevator is broken  38459.1219898966
#  elevator is broken  42741.11111644416
#  elevator is broken  43073.53688309231
#  elevator is broken  49068.925418099745
#  elevator is broken  49542.412004965554
#  elevator is broken  1700
#  elevator is broken  5385
#  elevator is broken  11045
#  elevator is broken  13645
#  elevator is broken  31352.077767881543
#  elevator is broken  31836.924598228936
#  elevator is broken  35150.43847457369
#  elevator is broken  45773.932227256206
#  elevator is broken  46790.54542537416
#  elevator is broken  48377.58172673531
#  elevator is broken  19455
#  elevator is broken  38610
#  elevator is broken  47535
#  elevator is broken  580
#  elevator is broken  9679.886445229587
#  elevator is broken  11825
#  elevator is broken  13555
#  elevator is broken  23300
#  elevator is broken  23896.128864139115
#  elevator is broken  25616.46108730334
#  elevator is broken  39755.65986638321
#  elevator is broken  49019.22091926949
#  elevator is broken  345
#  elevator is broken  15205
#  elevator is broken  18815
#  elevator is broken  22673.397240345697
#  elevator is broken  23847.128309080756
#  elevator is broken  23850
#  elevator is broken  27045.691680393746
#  elevator is broken  28134.825243651365
#  elevator is broken  33668.830730179594
#  elevator is broken  41035.12163448176
#  elevator is broken  41996.33127613085
#  elevator is broken  48384.124169865994
#  elevator is broken  1545
#  elevator is broken  7485
#  elevator is broken  8199.913882929262
#  elevator is broken  8640
#  elevator is broken  11577.98865464978
#  elevator is broken  20156.228159356324
#  elevator is broken  21505
#  elevator is broken  25130.98284950691
#  elevator is broken  31226.862597094776
#  elevator is broken  32284.82710152504
#  elevator is broken  47496.59637714627
#  elevator is broken  49057.11014878344
#  elevator is broken  49821.24359073591
#  elevator is broken  180
#  elevator is broken  4365
#  elevator is broken  4977.521316742656
#  elevator is broken  11779.282509584313
#  elevator is broken  21685
#  elevator is broken  23705
#  elevator is broken  23731.590776296925
#  elevator is broken  28552.38671545928
#  elevator is broken  39404.723487672665
#  elevator is broken  39992.03971886153
#  elevator is broken  42841.02653068717
#  elevator is broken  7635
#  elevator is broken  19265
#  elevator is broken  21593.687823732587
#  elevator is broken  23645.76859362792
#  elevator is broken  23837.962668151536
#  elevator is broken  24816.094076697947
#  elevator is broken  26610.78108321531
#  elevator is broken  33575
#  elevator is broken  46170
#  elevator is broken  16555
#  elevator is broken  27382.96436586062
#  elevator is broken  35370
#  elevator is broken  36939.86191971869
#  elevator is broken  47039.580962223896
#  elevator is broken  5800
#  elevator is broken  11335
#  elevator is broken  18930.00461415406
#  elevator is broken  25134.07553967376
#  elevator is broken  30265
#  elevator is broken  34155
#  elevator is broken  37522.27274466629
#  elevator is broken  47940.770956862834
#  elevator is broken  2665
#  elevator is broken  14530
#  elevator is broken  14895
#  elevator is broken  16316.701481952223
#  elevator is broken  17865
#  elevator is broken  18209.325547316526
#  elevator is broken  21792.59549572892
#  elevator is broken  26664.716164689165
#  elevator is broken  32017.157259950935
#  elevator is broken  34691.55760004606
#  elevator is broken  45378.50337186563
#  elevator is broken  48514.318281064625
#  elevator is broken  5
#  elevator is broken  13826.118371233155
#  elevator is broken  19765
#  elevator is broken  21780
#  elevator is broken  25797.052035616078
#  elevator is broken  39543.39887311993
#  elevator is broken  41314.16734932697
#  elevator is broken  43955
#  elevator is broken  47453.91523948585
#  elevator is broken  215
#  elevator is broken  7085
#  elevator is broken  9011.705522669756
#  elevator is broken  13860
#  elevator is broken  19887.505930023162
#  elevator is broken  26901.79937875584
#  elevator is broken  27842.83798345841
#  elevator is broken  38584.079059244745
#  elevator is broken  39929.88201942346
#  elevator is broken  42625
#  elevator is broken  42766.655594010736
#  elevator is broken  48654.93639215792
#  elevator is broken  5525
#  elevator is broken  6485
#  elevator is broken  11257.899853486713
#  elevator is broken  14975
#  elevator is broken  20874.149049794163
#  elevator is broken  23514.384909077082
#  elevator is broken  28402.687346197315
#  elevator is broken  29548.25847327646
#  elevator is broken  33851.55511866459
#  elevator is broken  35036.23919238204
#  elevator is broken  39458.279375403916
#  elevator is broken  43026.53457443309
#  elevator is broken  3505
#  elevator is broken  19625
#  elevator is broken  25315
#  elevator is broken  29898.97457360517
#  elevator is broken  30450
#  elevator is broken  32151.27974988126
#  elevator is broken  33397.07060144744
#  elevator is broken  35431.54160465533
#  elevator is broken  49493.676930197595
#  elevator is broken  2525
#  elevator is broken  4510
#  elevator is broken  6015
#  elevator is broken  9185.3012063558
#  elevator is broken  13195.958766842517
#  elevator is broken  26576.179480668085
#  elevator is broken  26764.287185776127
#  elevator is broken  27942.325976283395
#  elevator is broken  33621.327832974246
#  elevator is broken  34047.17499534643
#  elevator is broken  35895
#  elevator is broken  37127.46313579001
#  elevator is broken  45885.77736700844
#  elevator is broken  395
#  elevator is broken  7505
#  elevator is broken  9305.90740029882
#  elevator is broken  20445
#  elevator is broken  21880.253046191552
#  elevator is broken  25241.868571737537
#  elevator is broken  50170
#  elevator is broken  6885
#  elevator is broken  9525
#  elevator is broken  17515
#  elevator is broken  33723.42935159679
#  elevator is broken  35197.22190468805
#  elevator is broken  37855.32278064891
#  elevator is broken  46440
#  elevator is broken  7760
#  elevator is broken  30165
#  elevator is broken  32225
#  elevator is broken  34915
#  elevator is broken  36787.37356646226
#  elevator is broken  6205
#  elevator is broken  9460
#  elevator is broken  12345
#  elevator is broken  16476.690606501867
#  elevator is broken  23124.7976776947
#  elevator is broken  23870.95996424606
#  elevator is broken  26601.03570246637
#  elevator is broken  29933.03855791666
#  elevator is broken  32993.61378109762
#  elevator is broken  39085
#  elevator is broken  49461.31285585695
#  elevator is broken  50168.063837654
#  elevator is broken  2460
#  elevator is broken  7735
#  elevator is broken  33415.80026694559
#  elevator is broken  44215
#  elevator is broken  11655
#  elevator is broken  19036.678570805532
#  elevator is broken  23810
#  elevator is broken  26751.1312320781
#  elevator is broken  29995
#  elevator is broken  31488.01723367152
#  elevator is broken  32064.11366039493
#  elevator is broken  33535
#  elevator is broken  35213.75516974669
#  elevator is broken  43875.25000743863
#  elevator is broken  44233.32867514578
#  elevator is broken  46222.50496276425
#  elevator is broken  49846.1407234908
#  elevator is broken  685
#  elevator is broken  5145
#  elevator is broken  12560
#  elevator is broken  16215
#  elevator is broken  26752.753698680706
#  elevator is broken  26906.432507154394
#  elevator is broken  27593.531750749276
#  elevator is broken  28182.92983908334
#  elevator is broken  29704.469513519147
#  elevator is broken  31872.3120844191
#  elevator is broken  36214.83888039671
#  elevator is broken  45240.31266331857
#  elevator is broken  905
#  elevator is broken  3727.089223347416
#  elevator is broken  12395.639848200408
#  elevator is broken  16805
#  elevator is broken  22768.27961416954
#  elevator is broken  30410
#  elevator is broken  31865
#  elevator is broken  33347.043053136586
#  elevator is broken  45094.050157382684
#  elevator is broken  5595
#  elevator is broken  25103.084986422116
#  elevator is broken  26719.782526889234
#  elevator is broken  41915
#  elevator is broken  42370
#  elevator is broken  47515
#  elevator is broken  6645
#  elevator is broken  8025
#  elevator is broken  10345
#  elevator is broken  12351.2772519403
#  elevator is broken  12801.770790976843
#  elevator is broken  15427.480987257533
#  elevator is broken  21056.205860137175
#  elevator is broken  24056.01781875926
#  elevator is broken  29755.624602131174
#  elevator is broken  38379.25303144846
#  elevator is broken  38874.94220369338
#  elevator is broken  5710
#  elevator is broken  10625
#  elevator is broken  28485
#  elevator is broken  33075.51207738349
#  elevator is broken  33335
#  elevator is broken  5285
#  elevator is broken  16775
#  elevator is broken  22409.376573953195
#  elevator is broken  22680
#  elevator is broken  26515.986709466906
#  elevator is broken  29143.050472079773
#  elevator is broken  31115.904512356843
#  elevator is broken  33580.723761173256
#  elevator is broken  43568.16356066677
#  elevator is broken  49367.053871748576
#  elevator is broken  2230
#  elevator is broken  7221.776735276602
#  elevator is broken  20035
#  elevator is broken  22455
#  elevator is broken  26165
#  elevator is broken  34149.428823837094
#  elevator is broken  46144.717952876636
#  elevator is broken  48187.13486852907
#  elevator is broken  49942.41903228772
#  elevator is broken  2910
#  elevator is broken  3055
#  elevator is broken  5669.500100979429
#  elevator is broken  5709.003583127142
#  elevator is broken  11346.194084485433
#  elevator is broken  15135
#  elevator is broken  18815
#  elevator is broken  20202.489317896176
#  elevator is broken  24880.714480952804
#  elevator is broken  31080.191513484002
#  elevator is broken  32784.523644696725
#  elevator is broken  37221.60498757897
#  elevator is broken  47959.39272857702
#  elevator is broken  6375
#  elevator is broken  12784.126229255577
#  elevator is broken  20395
#  elevator is broken  20425
#  elevator is broken  27712.547212640784
#  elevator is broken  40895.400056737395
#  elevator is broken  45167.38771122953
#  elevator is broken  4895
#  elevator is broken  10220
#  elevator is broken  18934.222883693088
#  elevator is broken  23179.224993557367
#  elevator is broken  24197.897838459605
#  elevator is broken  27515
#  elevator is broken  33175
#  elevator is broken  38868.91135936581
#  elevator is broken  42302.64059710743
#  elevator is broken  695
#  elevator is broken  2970
#  elevator is broken  23465
#  elevator is broken  27155
#  elevator is broken  28189.522644469667
#  elevator is broken  29427.859457398157
#  elevator is broken  33337.28172352676
#  elevator is broken  34989.29939333001
#  elevator is broken  37333.605186324035
#  elevator is broken  45054.15682090965
#  elevator is broken  46220.086713478355
#  elevator is broken  12380
#  elevator is broken  17807.571659195808
#  elevator is broken  22945
#  elevator is broken  26275
#  elevator is broken  28835.18838710736
#  elevator is broken  42815
#  elevator is broken  44428.86082780028
#  elevator is broken  45126.26756692163
#  elevator is broken  45694.16291780672
#  elevator is broken  5315
#  elevator is broken  7354.14574761343
#  elevator is broken  8585
#  elevator is broken  11080
#  elevator is broken  30163.7515218299
#  elevator is broken  30360.00544844323
#  elevator is broken  31171.70618306597
#  elevator is broken  31985
#  elevator is broken  32697.569372659833
#  elevator is broken  32940.54572495645
#  elevator is broken  36294.46676996381
#  elevator is broken  38816.41335965997
#  elevator is broken  47784.79575454839
#  elevator is broken  275
#  elevator is broken  635
#  elevator is broken  3735
#  elevator is broken  4769.609445361788
#  elevator is broken  10976.8478886148
#  elevator is broken  21550.615259112652
#  elevator is broken  29760
#  elevator is broken  30972.495702247772
#  elevator is broken  32635.589464630324
#  elevator is broken  45763.19012320299
#  elevator is broken  49675.591375181946
#  elevator is broken  6755
#  elevator is broken  9007.091542069407
#  elevator is broken  18144.721393585613
#  elevator is broken  23280
#  elevator is broken  30095
#  elevator is broken  37450.70727570939
#  elevator is broken  41050.54374486793
#  elevator is broken  41511.0401822919
#  elevator is broken  41674.94557094263
#  elevator is broken  43601.83676289187
#  elevator is broken  46430.90179433786
#  elevator is broken  47561.983182458695
#  elevator is broken  2030
#  elevator is broken  4355
#  elevator is broken  5515
#  elevator is broken  16627.7562386477
#  elevator is broken  22085
#  elevator is broken  26047.466806958735
#  elevator is broken  30452.76490191379
#  elevator is broken  39103.76419982517
#  elevator is broken  46946.12316685965
#  elevator is broken  7675
#  elevator is broken  8225
#  elevator is broken  9925
#  elevator is broken  11621.580805366482
#  elevator is broken  15252.194392015614
#  elevator is broken  18545.901688911403
#  elevator is broken  22220
#  elevator is broken  23584.245320632457
#  elevator is broken  27316.407853260258
#  elevator is broken  29657.343430035435
#  elevator is broken  33311.77825517238
#  elevator is broken  35112.852288430324
#  elevator is broken  48972.584630062425
#  elevator is broken  5425
#  elevator is broken  10766.557398891553
#  elevator is broken  21835
#  elevator is broken  28849.903930841683
#  elevator is broken  30313.596161250836
#  elevator is broken  40861.578922343935
#  elevator is broken  42445.914317387236
#  elevator is broken  45615
#  elevator is broken  10480
#  elevator is broken  14575
#  elevator is broken  32945
#  elevator is broken  33719.1388614607
#  elevator is broken  42990.7323519533
#  elevator is broken  43255
#  elevator is broken  46644.91121685975
#  elevator is broken  13490
#  elevator is broken  14784.53761918923
#  elevator is broken  14825
#  elevator is broken  22904.9899084828
#  elevator is broken  25123.739046230912
#  elevator is broken  26775.109427546085
#  elevator is broken  28915
#  elevator is broken  32945
#  elevator is broken  35927.06523986722
#  elevator is broken  39936.96115242614
#  elevator is broken  40704.99272860488
#  elevator is broken  44741.02287258359
#  elevator is broken  275
#  elevator is broken  22725
#  elevator is broken  32570
#  elevator is broken  32575.296290620587
#  elevator is broken  34465.3624222937
#  elevator is broken  45378.02748800473
#  elevator is broken  2585
#  elevator is broken  4106.351400389805
#  elevator is broken  6550
#  elevator is broken  12935
#  elevator is broken  14819.405600789454
#  elevator is broken  21255.43649237751
#  elevator is broken  28921.261481425077
#  elevator is broken  29043.74249852514
#  elevator is broken  30712.01080670821
#  elevator is broken  36486.88049773585
#  elevator is broken  36521.00558094859
#  elevator is broken  49536.75900630915
#  elevator is broken  50228.4895990896
#  elevator is broken  3315
#  elevator is broken  5265
#  elevator is broken  16319.921791015448
#  elevator is broken  20740
#  elevator is broken  23702.034896451125
#  elevator is broken  24312.89572824377
#  elevator is broken  11695
#  elevator is broken  28180
#  elevator is broken  30845
#  elevator is broken  32774.96284220017
#  elevator is broken  34875.00220227484
#  elevator is broken  3800
#  elevator is broken  4715
#  elevator is broken  10762.593028082185
#  elevator is broken  13925
#  elevator is broken  15831.861311629447
#  elevator is broken  23775
#  elevator is broken  29177.759082848643
#  elevator is broken  36984.591295745544
#  elevator is broken  39127.45923861455
#  elevator is broken  1545
#  elevator is broken  1760
#  elevator is broken  13465
#  elevator is broken  14245.086274968682
#  elevator is broken  16606.75170755293
#  elevator is broken  19066.149362154265
#  elevator is broken  19547.587128676845
#  elevator is broken  33574.56368856284
#  elevator is broken  50224.597211079184
#  elevator is broken  2965
#  elevator is broken  28255
#  elevator is broken  32037.754565713207
#  elevator is broken  34790.838404024435
#  elevator is broken  42036.59270303454
#  elevator is broken  1465
#  elevator is broken  9120.921850724202
#  elevator is broken  12850
#  elevator is broken  27669.231188710386
#  elevator is broken  44645
#  elevator is broken  45259.327726465366
#  elevator is broken  45943.53857415078
#  elevator is broken  585
#  elevator is broken  5185
#  elevator is broken  6375
#  elevator is broken  14090
#  elevator is broken  19415.547637168092
#  elevator is broken  26996.446091752303
#  elevator is broken  27322.467969708432
#  elevator is broken  34578.63428567311
#  elevator is broken  43324.24900103135
#  elevator is broken  47541.86116407282
#  elevator is broken  50026.59645920972
#  elevator is broken  6995
#  elevator is broken  15155
#  elevator is broken  21005
#  elevator is broken  23555.063191377878
#  elevator is broken  24760
#  elevator is broken  29851.727233064194
#  elevator is broken  35266.77140685063
#  elevator is broken  36395.17813788581
#  elevator is broken  39444.46943733131
#  elevator is broken  47249.39618300338
#  elevator is broken  48487.3289788887
#  elevator is broken  49748.004815160864
#  elevator is broken  17125
#  elevator is broken  22660
#  elevator is broken  34885
#  elevator is broken  43391.99552493058
#  elevator is broken  43940.87162182882
#  elevator is broken  45998.21342209847
#  elevator is broken  7665
#  elevator is broken  8355
#  elevator is broken  12805
#  elevator is broken  15700
#  elevator is broken  24510.035240634003
#  elevator is broken  30870.88979547489
#  elevator is broken  37891.24332290221
#  elevator is broken  40845.324825580785
#  elevator is broken  5545
#  elevator is broken  14555
#  elevator is broken  18485
#  elevator is broken  29009.34085147532
#  elevator is broken  29960
#  elevator is broken  36335.61126809396
#  elevator is broken  37099.58926959346
#  elevator is broken  38473.96865639483
#  elevator is broken  39295.60691884447
#  elevator is broken  39306.42914603267
#  elevator is broken  48071.8000596005
#  elevator is broken  49033.41542931525
#  elevator is broken  16440
#  elevator is broken  24441.88213181174
#  elevator is broken  25835
#  elevator is broken  40335
#  elevator is broken  47100.890004903325
#  elevator is broken  1335
#  elevator is broken  10030.369303092473
#  elevator is broken  13665
#  elevator is broken  19900
#  elevator is broken  20490.386677584775
#  elevator is broken  24591.341988738233
#  elevator is broken  31212.569066569948
#  elevator is broken  32825
#  elevator is broken  34184.40061247699
#  elevator is broken  46227.69989326064
#  elevator is broken  5515
#  elevator is broken  6785
#  elevator is broken  10175
#  elevator is broken  16778.007656353315
#  elevator is broken  20885.937116075056
#  elevator is broken  27811.539033961308
#  elevator is broken  28227.56561175675
#  elevator is broken  29524.57831031389
#  elevator is broken  31259.324249982466
#  elevator is broken  38455.19496062206
#  elevator is broken  47805.11911294779
#  elevator is broken  49120
#  elevator is broken  50247.21594434293
#  elevator is broken  7335
#  elevator is broken  9205
#  elevator is broken  32705
#  elevator is broken  40014.17847016381
#  elevator is broken  40038.68052757043
#  elevator is broken  43753.93327578878
#  elevator is broken  48468.93583014949

# %%
########  FIRST

#lypo = np.array(service_time)
#print(sorted(service_time,reverse=True))

#print(sorted(service_time,reverse=True)[0:-3])
#lypo = pd.Series(sorted(service_time)[0:-3])
lypo = pd.Series(service_time)

fig = lypo.hist(bins = 100,edgecolor='k',figsize=(12,6)).set_ylabel("service time distribution")

#lypo.plot.hist(bins=60, edgecolor='k').autoscale(enable=True, axis='both', tight=True)
#skt1 = pd.cut(service_time,200).value_counts()
#print(skt1)
#skt1.hist()

# %%
### Average of out of patience passengers ###
needed_average = sum(avg_out_of_patience)/len(avg_out_of_patience)
print("Average of out of patience passengers: ",needed_average)
# Out:
# Average of out of patience passengers:  42.8

# %%
### התפלגות תפוסת המעליות ###
mock = []# 4x16 array because there can be 0-15 people in elevator, and there are 4 elevators
#creating the mock array
for elvtor in range(4):
    plp = np.random.random(16)*10
    mock.append(list(plp))



mat1 = []
mat2 = []
mat3 = []
mat4 = []

for i in range(16):
    mat1.append([i,elevator_usage[0][i]]) 

for i in range(16):
    mat2.append([i,elevator_usage[1][i]])

for i in range(16):
    mat3.append([i,elevator_usage[2][i]]) 

for i in range(16):
    mat4.append([i,elevator_usage[3][i]]) 
df1 = pd.DataFrame(mat1, columns=["no. of passengers", "time"]) # hold the data in a pandas Data Frame object
title='elevator1'
df1.plot.bar(x="num_of_people", y="time",figsize=(12,3), title=title); #bar plot

# %%
df2 = pd.DataFrame(mat2, columns=["no. of passengers", "time"]) # hold the data in a pandas Data Frame object
title='elevator2'
df2.plot.bar(x="num_of_people", y="time",figsize=(12,3), title=title); #bar plot

# %%
df3 = pd.DataFrame(mat3, columns=["no. of passengers", "time"]) # hold the data in a pandas Data Frame object
title='elevator3'
df3.plot.bar(x="num_of_people", y="time",figsize=(12,3), title=title); #bar plot

# %%
df4 = pd.DataFrame(mat4, columns=["no. of passengers", "time"]) # hold the data in a pandas Data Frame object
title='elevator4'
df4.plot.bar(x="num_of_people", y="time",figsize=(12,3), title=title); #bar plot
